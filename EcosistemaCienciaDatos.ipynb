# %% [markdown]
# # Herramientas y Ecosistema de Ciencia de Datos

# %% [markdown]
# En este cuaderno se resumen las herramientas y el ecosistema de la Ciencia de Datos.

# %% [markdown]
# **Objetivos:**
# - Enumerar lenguajes populares para la Ciencia de Datos
# - Enumerar bibliotecas utilizadas comúnmente
# - Crear tablas en Markdown
# - Realizar operaciones aritméticas en Python

# %% [markdown]
# Algunos de los lenguajes más populares que usan los científicos de datos son:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Algunas de las bibliotecas comúnmente utilizadas por los científicos de datos incluyen:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib

# %% [markdown]
# | Herramientas de Ciencia de Datos |
# |------------------------------|
# | Jupyter Notebook             |
# | RStudio                      |
# | Apache Zeppelin              |

# %% [markdown]
# ### A continuación se presentan algunos ejemplos de evaluación de expresiones aritméticas en Python.

# %%
# Esta es una expresión aritmética simple que multiplica y luego suma enteros
(3 * 4) + 5

# %%
# Esto convertirá 200 minutos a horas dividiendo por 60
200 / 60

# %% [markdown]
# ## Autor
# Ricardo Jaramillo Pulgar
